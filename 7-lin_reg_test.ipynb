# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('lr_ex').getOrCreate()

# %%
from pyspark.ml.regression import LinearRegression

# %%
data = spark.read.csv("/FileStore/tables/cruise_ship_info.csv",inferSchema=True,header=True)

# %%
data.printSchema()
# Out:
# root
#  |-- Ship_name: string (nullable = true)
#  |-- Cruise_line: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Tonnage: double (nullable = true)
#  |-- passengers: double (nullable = true)
#  |-- length: double (nullable = true)
#  |-- cabins: double (nullable = true)
#  |-- passenger_density: double (nullable = true)
#  |-- crew: double (nullable = true)

# %%
data.show()
# Out:
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+
# |  Ship_name|Cruise_line|Age|           Tonnage|passengers|length|cabins|passenger_density|crew|
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+
# |    Journey|    Azamara|  6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|
# |      Quest|    Azamara|  6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|
# |Celebration|   Carnival| 26|            47.262|     14.86|  7.22|  7.43|             31.8| 6.7|
# |   Conquest|   Carnival| 11|             110.0|     29.74|  9.53| 14.88|            36.99|19.1|
# |    Destiny|   Carnival| 17|           101.353|     26.42|  8.92| 13.21|            38.36|10.0|
# |    Ecstasy|   Carnival| 22|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|
# |    Elation|   Carnival| 15|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|
# ...

# %%
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import (VectorAssembler,StringIndexer)

# %%
data.columns
# Out:
# Out[11]: ['Ship_name',
#  'Cruise_line',
#  'Age',
#  'Tonnage',
#  'passengers',
#  'length',
#  'cabins',
#  'passenger_density',
#  'crew']

# %%
indexer = StringIndexer(inputCol="Cruise_line", outputCol="line_index").fit(data)

# %%
data_ind = indexer.transform(data)
data_ind.show()
# Out:
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+----------+
# |  Ship_name|Cruise_line|Age|           Tonnage|passengers|length|cabins|passenger_density|crew|line_index|
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+----------+
# |    Journey|    Azamara|  6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|      16.0|
# |      Quest|    Azamara|  6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|      16.0|
# |Celebration|   Carnival| 26|            47.262|     14.86|  7.22|  7.43|             31.8| 6.7|       1.0|
# |   Conquest|   Carnival| 11|             110.0|     29.74|  9.53| 14.88|            36.99|19.1|       1.0|
# |    Destiny|   Carnival| 17|           101.353|     26.42|  8.92| 13.21|            38.36|10.0|       1.0|
# |    Ecstasy|   Carnival| 22|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|       1.0|
# ...

# %%
data_ind.columns
# Out:
# Out[14]: ['Ship_name',
#  'Cruise_line',
#  'Age',
#  'Tonnage',
#  'passengers',
#  'length',
#  'cabins',
#  'passenger_density',
#  'crew',
#  'line_index']

# %%
assembler = VectorAssembler(inputCols=['Age',
 'Tonnage',
 'passengers',
 'length',
 'cabins',
 'passenger_density',
 'line_index'],outputCol = 'features')

# %%
output = assembler.transform(data_ind)

# %%
output.head(1)
# Out:
# Out[18]: [Row(Ship_name='Journey', Cruise_line='Azamara', Age=6, Tonnage=30.276999999999997, passengers=6.94, length=5.94, cabins=3.55, passenger_density=42.64, crew=3.55, line_index=16.0, features=DenseVector([6.0, 30.277, 6.94, 5.94, 3.55, 42.64, 16.0]))]

# %%
final_data = output.select('features','crew')

# %%
final_data.show()
# Out:
# +--------------------+----+
# |            features|crew|
# +--------------------+----+
# |[6.0,30.276999999...|3.55|
# |[6.0,30.276999999...|3.55|
# |[26.0,47.262,14.8...| 6.7|
# |[11.0,110.0,29.74...|19.1|
# |[17.0,101.353,26....|10.0|
# |[22.0,70.367,20.5...| 9.2|
# |[15.0,70.367,20.5...| 9.2|
# |[23.0,70.367,20.5...| 9.2|
# |[19.0,70.367,20.5...| 9.2|
# |[6.0,110.23899999...|11.5|
# |[10.0,110.0,29.74...|11.6|
# |[28.0,46.052,14.5...| 6.6|
# |[18.0,70.367,20.5...| 9.2|
# |[17.0,70.367,20.5...| 9.2|
# |[11.0,86.0,21.24,...| 9.3|
# |[8.0,110.0,29.74,...|11.6|
# |[9.0,88.5,21.24,9...|10.3|
# |[15.0,70.367,20.5...| 9.2|
# |[12.0,88.5,21.24,...| 9.3|
# |[20.0,70.367,20.5...| 9.2|
# +--------------------+----+
# only showing top 20 rows

# %%
train_data,test_data = final_data.randomSplit([0.8,0.2])

# %%
lr = LinearRegression(labelCol='crew')

# %%
lr_model = lr.fit(train_data)

# %%
test_results = lr_model.evaluate(test_data)

# %%
test_results.residuals.show()
# Out:
# /databricks/spark/python/pyspark/sql/context.py:134: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# +--------------------+
# |           residuals|
# +--------------------+
# |  0.3004834081217922|
# |  0.8536591737092403|
# | -1.6082911856046689|
# |  -0.758930123957402|
# |-0.27826843884694696|
# |-0.21021884060516527|
# | 0.32599060198324814|
# | -0.6829647830510783|
# | -0.6018313505301656|
# |  1.7861891898709237|
# | 0.11527451206172135|
# | -0.8088135811811696|
# |  0.8728802074264017|
# | 0.06677198682408159|
# |  0.7306826450596393|
# |-0.16688489411486707|
# | -0.5068349930947855|
# |   0.793752395843935|
# |  0.2316062500018763|
# | -0.8326919219613576|
# +--------------------+
# only showing top 20 rows

# %%
test_results.rootMeanSquaredError
# Out:
# Out[26]: 0.7899007361885741

# %%
test_results.r2
# Out:
# Out[27]: 0.9238790533010364
